# %%
from goseidataset import DatasetGenerator

# %%
dg = DatasetGenerator()

# %%
import goseidataset

print(goseidataset.__file__)
# Out:
# /home/harihara-suthan-s/Gosei dataset/src/goseidataset/__init__.py

# %%
import inspect
from goseidataset import DatasetGenerator

print(
    inspect.signature(
        DatasetGenerator.generate_random
    )
)
# Out:
# (self, n_rows, constraints, bias=None, dtypes=None)

# %%
df = dg.generate_random(
    n_rows=10,
    constraints={
        "age": [18, 60],
        "salary": [30000, 90000],
        "cgpa": [0, 10],
        "session": ["M", "J"]
    },
    dtypes={
        "age": "int",
        "salary": "int",
        "cgpa": "float"
    }
)

print(df)
# Out:
#    age  salary      cgpa session
# 0   21   85149  8.792583       M
# 1   46   86631  7.360555       M
# 2   23   62235  0.258942       J
# 3   38   69253  3.786293       J
# 4   36   35327  3.703327       J
# 5   19   30940  9.534111       M
# 6   43   71883  8.626349       J
# 7   44   40438  1.211269       J
# 8   58   41410  5.374898       J
# 9   57   53422  4.346205       J

# %%
df = dg.generate_random(
    n_rows=1000,
    constraints={
        "score":[0,100]
    },
    bias={
        "score":"high"
    }
)

df["score"].mean()
# Out:
# np.float64(71.01358730747144)

# %%
df = dg.generate_random(
    n_rows=1000,
    constraints={
        "score":[0,100]
    },
    bias={
        "score":"low"
    }
)

df["score"].mean()
# Out:
# np.float64(27.814885735517485)

# %%
df = dg.generate_random(
    n_rows=1000,
    constraints={
        "score":[0,100]
    },
    bias={
        "score":"center"
    }
)

df["score"].mean()
# Out:
# np.float64(50.31783716459647)

# %%
df = dg.generate_random(
    n_rows=1000,
    constraints={
        "score":[0,100]
    },
    bias={
        "score":80
    }
)

df["score"].mean()
# Out:
# np.float64(78.87964612399205)

# %%
dg.generate_random(
    n_rows=10,
    constraints={
        "age":[60,18]
    }
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dg.generate_random(
#       2     n_rows=10,
#       3     constraints={
#       4         "age":[60,18]
#
# File ~/Gosei dataset/src/goseidataset/generatedataset.py:157, in DatasetGenerator.generate_random(self, n_rows, constraints, bias, dtypes)
#     154 max_value = values[1]
#     156 if min_value > max_value:
# --> 157     raise ValueError(
#     158         f"{column}: minimum value "
#     159         "cannot be greater than "
#     160         "maximum value."
#     161     )
#     163 column_bias = bias.get(
#     164     column,
#     165     None
#     166 )
#     168 # No bias
#
# ValueError: age: minimum value cannot be greater than maximum value.
